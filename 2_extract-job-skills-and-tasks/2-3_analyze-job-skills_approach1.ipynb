# %% [markdown]
# # 3-2. Analyze Extracted Job Skills
#
# Job posting data is provided by: https://www.kaggle.com/datasets/arshkon/linkedin-job-postings
#
# Author: Yu Kyung Koh
#
# Last Updated: 2025/05/17

# %%
import pandas as pd
import os
import re
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from collections import Counter

# %% [markdown]
# ## SECTION 1: Wordcloud for most required skill for each category

# %%
## Import cleaned data from STEP 3-1
cleandatadir = '/Users/yukyungkoh/Desktop/1_Post-PhD/7_Python-projects/2_practice-NLP_job-posting/2_data/cleaned_data'
jobdata = os.path.join(cleandatadir, '3_job-posting_skills-extracted_df.pkl')
jobs_df = pd.read_pickle(jobdata, 'zip')

# %%
jobs_df.head(10)
# Out:
#        job_id                             company_name  \
# 0      921716                    Corcoran Sawyer Smith
# 2    10998357                   The National Exemplar
# 12   56482768                                      NaN
# 14   69333422                          Staffing Theory
# 18  111513530  United Methodists of Greater New Jersey
# 22  133130219                                      NaN
# 26  175485704                                     GOYT
# 35  266566927                       Revesco Properties
# 46  805229245                                      NaN
# 47  844454682                                      NaN
#
#                                             title  work_type  \
# 0                           Marketing Coordinator  FULL_TIME
# 2                     Assitant Restaurant Manager  FULL_TIME
# 12  Appalachian Highlands Women's Business Center  FULL_TIME
# 14               Senior Product Marketing Manager  FULL_TIME
# 18                 Content Writer, Communications  FULL_TIME
# 22                              Software Engineer  FULL_TIME
# 26                              Software Engineer  PART_TIME
# 35                 Marketing & Office Coordinator  FULL_TIME
# 46                       Manager, Retail Pharmacy  FULL_TIME
# 47                    Commercial Property Manager  FULL_TIME
#
#     normalized_salary                                      combined_desc  \
# 0             38480.0  Job description A leading real estate firm in ...
# 2             55000.0  The National Exemplar is accepting application...
# 12                NaN  FULL JOB DESCRIPTION – PROGRAM DIRECTOR Appala...
# 14                NaN  A leading pharmaceutical company committed to ...
# 18                NaN  Application opening date : April 24, 2024\nTit...
# 22                NaN  Education Bachelor ' s degree in software , ma...
# 26                NaN  Job Description : GOYT is seeking a skilled an...
# 35            65000.0  About Revesco Properties : Revesco Properties ...
# 46           137500.0  SUMMARY : Manages operation and supervises all...
# 47                NaN  Gordon Partners ( www . gordonpartners . com )...
#
#             job_category                            combined_desc_corrected  \
# 0              Marketing  job description a leading real estate firm in ...
# 2          Other Manager  the national exemplar is accepting application...
# 12  Business/Finance Job  full job description – program director appala...
# 14             Marketing  a leading pharmaceutical company committed to ...
# 18             Marketing  application opening date : april 24, 2024 titl...
# 22    Software/Developer  education bachelor ' s degree in software , ma...
# 26    Software/Developer  job description : goyt is seeking a skilled an...
# 35             Marketing  about revesco properties : revesco properties ...
# 46         Other Manager  summary : manages operation and supervises all...
# 47         Other Manager  gordon partners ( www . gordonpartners . com )...
#
#                                      skills_extracted
# 0   [graphic design, social media, online advertis...
# 2                             [restaurant management]
# 12  [social media, programming, technical leadersh...
# 14  [market environment, patient advocacy, promoti...
# 18  [jersey, journalism, photography, seo tools, m...
# 22                                                 []
# 26  [emerging technologies, relational databases, ...
# 35  [social media, brand management, event plannin...
# 46  [pharmacy systems, pharmacy experience, pharma...
# 47  [property management, yardi, vendor contracts,...

# %%
#jobs_df["skills_temp"][7]

# %%
#jobs_df["skills_extracted"][7]

# %%
# Group by job category and count skills
grouped_skills = jobs_df.groupby("job_category")["skills_extracted"].apply(
    lambda lists: sum(lists.dropna().tolist(), [])  # flatten the list of lists
)

# %%
# Loop through each category and create word clouds
for category, skills in grouped_skills.items():
    if not skills:  # skip if empty
        continue

    # Count frequency of each skill
    skill_freq = Counter(skills)

    # Create and configure WordCloud
    wordcloud = WordCloud(width=800, height=400, background_color='white', colormap='viridis')
    wordcloud.generate_from_frequencies(skill_freq)

    # Plot the WordCloud
    plt.figure(figsize=(12, 6))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis("off")
    plt.title(f"Top Skills in '{category}' Jobs", fontsize=16)
    plt.show()
