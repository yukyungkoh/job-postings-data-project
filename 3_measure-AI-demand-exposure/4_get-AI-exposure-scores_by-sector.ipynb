# %% [markdown]
# # 🏷️ Part 3.4 - Compute AI Exposure Scores by Sector
#
# **Author:** Yu Kyung Koh
# **Last Updated:** August 1, 2025
#
# ---
#
# ### 🎯 Objective
# * Compute the AI substituability and complementary scores by job sectors.
#
# ### 🗂️ Outline
# * **Section 1:** Import all necessary dataframes
# * **Section 2:** Link dataframes
# * **Section 3:** Get AI exposure scores by sector

# %% [markdown]
# ---
# ## Section 1: Import all necessary dataframes

# %%
import pandas as pd
import os
import re
import joblib
from tqdm import tqdm
from joblib import Parallel, delayed
import math

# %%
# --------------------------------------
# STEP 1: Import original job posting data with extracted tasks
# --------------------------------------
datadir = '../data/'
jobposting_file = os.path.join(datadir, 'sample_job_postings_with_tasks.csv')

posting_df = pd.read_csv(jobposting_file)
posting_df.head()
# Out:
#                           job_title  \
# 0  Sales Development Representative
# 1           Healthcare Data Analyst
# 2          Data Insights Specialist
# 3        Digital Content Strategist
# 4              Curriculum Developer
#
#                                         posting_text        sector  \
# 0  Join a dynamic team dedicated to driving innov...         sales
# 1  Join a dynamic team dedicated to improving pat...    healthcare
# 2  Join a dynamic team dedicated to unlocking the...  data science
# 3  At our innovative marketing agency, we believe...     marketing
# 4  Join a dynamic team dedicated to transforming ...     education
#
#                              extracted_tasks_mistral
# 0   - Identify and nurture leads to help expand t...
# 1   - Analyze large datasets related to healthcar...
# 2   - Analyze large datasets to extract actionabl...
# 3   - Research industry trends\n- Craft compellin...
# 4   - Design innovative learning materials and as...

# %%
## Generate "job_posting_index" -> necessary to merge the data later on
posting_df = posting_df.reset_index().rename(columns={"index": "job_posting_index"})
posting_df.head()
# Out:
#    job_posting_index                         job_title  \
# 0                  0  Sales Development Representative
# 1                  1           Healthcare Data Analyst
# 2                  2          Data Insights Specialist
# 3                  3        Digital Content Strategist
# 4                  4              Curriculum Developer
#
#                                         posting_text        sector  \
# 0  Join a dynamic team dedicated to driving innov...         sales
# 1  Join a dynamic team dedicated to improving pat...    healthcare
# 2  Join a dynamic team dedicated to unlocking the...  data science
# 3  At our innovative marketing agency, we believe...     marketing
# 4  Join a dynamic team dedicated to transforming ...     education
#
#                              extracted_tasks_mistral
# 0   - Identify and nurture leads to help expand t...
# 1   - Analyze large datasets related to healthcar...
# 2   - Analyze large datasets to extract actionabl...
# 3   - Research industry trends\n- Craft compellin...
# 4   - Design innovative learning materials and as...

# %%
# --------------------------------------
# STEP 2: Import task data with cluster assignment
# --------------------------------------
task_file = os.path.join(datadir, 'sample_job_postings_with_tasks-mapping.csv')

task_df = pd.read_csv(task_file)
task_df.head()
# Out:
#                                                 task  job_posting_index  \
# 0  identify and nurture leads to help expand the ...                  0
# 1  reach out to potential clients via email and p...                  0
# 2                                      qualify leads                  0
# 3           schedule meetings for account executives                  0
# 4       analyze large datasets related to healthcare                  1
#
#                                            embedding  cluster_kmeans  \
# 0  [0.007788926362991333, 0.03043454885482788, 0....               3
# 1  [-0.0873531699180603, 0.035773009061813354, 0....             192
# 2  [0.0034667470026761293, -0.014017626643180847,...             126
# 3  [0.0006416613468900323, -0.020684655755758286,...              71
# 4  [0.05672462657094002, 0.04137267917394638, -0....             103
#
#                                standardized_activity
# 0  Lead generation and relationship management in...
# 1          Client Engagement and Outreach Activities
# 2                  Lead Generation and Qualification
# 3  Scheduling and setting up meetings for sales t...
# 4  Data collection, cleaning, and analysis, parti...

# %%
# --------------------------------------
# STEP 3: Import AI score data for each standardized task
# --------------------------------------
AIscore_file = os.path.join(datadir, 'activity_ai_impact_flags.csv')

AIscore_df = pd.read_csv(AIscore_file)
AIscore_df.head()
# Out:
#    cluster_kmeans                              standardized_activity  \
# 0               0       Legal Research and Case Strategy Development
# 1               1    Team Collaboration and Communication Specialist
# 2               2  Collaboration with cross-functional teams for ...
# 3               3  Lead generation and relationship management in...
# 4               4  Facilitating professional development and trai...
#
#    ai_substitutable  ai_complementary
# 0               0.5               1.0
# 1               0.0               0.5
# 2               0.0               0.5
# 3               0.5               1.0
# 4               0.0               0.5

# %% [markdown]
# ---
# ## Section 2: Link dataframes

# %%
# --------------------------------------
# Step 1: Merge task-level tasks with activity-level AI scores
# --------------------------------------
task_with_scores_df = task_df.merge(
                        AIscore_df, 
                        on="cluster_kmeans", 
                        how="left")
task_with_scores_df.head()
# Out:
#                                                 task  job_posting_index  \
# 0  identify and nurture leads to help expand the ...                  0
# 1  reach out to potential clients via email and p...                  0
# 2                                      qualify leads                  0
# 3           schedule meetings for account executives                  0
# 4       analyze large datasets related to healthcare                  1
#
#                                            embedding  cluster_kmeans  \
# 0  [0.007788926362991333, 0.03043454885482788, 0....               3
# 1  [-0.0873531699180603, 0.035773009061813354, 0....             192
# 2  [0.0034667470026761293, -0.014017626643180847,...             126
# 3  [0.0006416613468900323, -0.020684655755758286,...              71
# 4  [0.05672462657094002, 0.04137267917394638, -0....             103
#
#                              standardized_activity_x  \
# 0  Lead generation and relationship management in...
# 1          Client Engagement and Outreach Activities
# 2                  Lead Generation and Qualification
# 3  Scheduling and setting up meetings for sales t...
# 4  Data collection, cleaning, and analysis, parti...
#
#                              standardized_activity_y  ai_substitutable  \
# 0  Lead generation and relationship management in...               0.5
# 1          Client Engagement and Outreach Activities               0.0
# 2                  Lead Generation and Qualification               0.5
# 3  Scheduling and setting up meetings for sales t...               0.5
# 4  Data collection, cleaning, and analysis, parti...               1.0
#
#    ai_complementary
# 0               1.0
# 1               0.5
# 2               1.0
# 3               1.0
# 4               1.0

# %%
# --------------------------------------
# Step 2: Merge in sector info from posting_df
# --------------------------------------
task_with_sector_df = task_with_scores_df.merge(
        posting_df[["job_posting_index", "sector"]],
        on="job_posting_index",
        how="left"
    )
task_with_sector_df.head()
# Out:
#                                                 task  job_posting_index  \
# 0  identify and nurture leads to help expand the ...                  0
# 1  reach out to potential clients via email and p...                  0
# 2                                      qualify leads                  0
# 3           schedule meetings for account executives                  0
# 4       analyze large datasets related to healthcare                  1
#
#                                            embedding  cluster_kmeans  \
# 0  [0.007788926362991333, 0.03043454885482788, 0....               3
# 1  [-0.0873531699180603, 0.035773009061813354, 0....             192
# 2  [0.0034667470026761293, -0.014017626643180847,...             126
# 3  [0.0006416613468900323, -0.020684655755758286,...              71
# 4  [0.05672462657094002, 0.04137267917394638, -0....             103
#
#                              standardized_activity_x  \
# 0  Lead generation and relationship management in...
# 1          Client Engagement and Outreach Activities
# 2                  Lead Generation and Qualification
# 3  Scheduling and setting up meetings for sales t...
# 4  Data collection, cleaning, and analysis, parti...
#
#                              standardized_activity_y  ai_substitutable  \
# 0  Lead generation and relationship management in...               0.5
# 1          Client Engagement and Outreach Activities               0.0
# 2                  Lead Generation and Qualification               0.5
# 3  Scheduling and setting up meetings for sales t...               0.5
# 4  Data collection, cleaning, and analysis, parti...               1.0
#
#    ai_complementary      sector
# 0               1.0       sales
# 1               0.5       sales
# 2               1.0       sales
# 3               1.0       sales
# 4               1.0  healthcare

# %% [markdown]
# ---
# ## Section 3: Get AI exposure scores by sector

# %%
# Group by sector and compute average substitutability and complementarity
sector_ai_scores = task_with_sector_df.groupby("sector")[["ai_substitutable", "ai_complementary"]].mean().reset_index()
sector_ai_scores = sector_ai_scores.sort_values(by="ai_substitutable", ascending=False)
sector_ai_scores
# Out:
#                   sector  ai_substitutable  ai_complementary
# 1           data science          0.587845          0.941989
# 3                finance          0.567522          0.887835
# 10  software engineering          0.506354          0.964321
# 6              marketing          0.500961          0.943804
# 5                  legal          0.498489          0.906344
# 4             healthcare          0.496802          0.892324
# 2              education          0.430045          0.902242
# 0             consulting          0.424847          0.862986
# 9                  sales          0.424103          0.889744
# 8                 retail          0.383140          0.832558
# 7          public sector          0.178138          0.650810
